# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.tri as tri
from matplotlib import cm
import numpy as np

import time

# %%
def ackley(x, a=20, b=0.2, c=2*np.pi):
    """
    x: vector of input values
    """
    d = len(x) # dimension of input vector x
    sum_sq_term = -a * np.exp(-b * np.sqrt(sum(x*x) / d))
    cos_term = -np.exp(sum(np.cos(c*x) / d))
    return a + np.exp(1) + sum_sq_term + cos_term

# %%
# The values in the array should range between -32 and 32
MIN_RANGE = -32
MAX_RANGE = 32
npts = 200
ngridx = 100
ngridy = 200
x_array =np.array([])

defined_length = 1000

x = np.linspace(-32, 32, 1000)
start_time = time.time()

new_x = np.array([0,0])
x_temp = np.array([])
for i in range(defined_length):
    x_temp = np.vstack((x[i]*np.ones(defined_length), x.flatten())).T
#     print(i)
    new_x = np.row_stack((new_x,x_temp))
    
print('finished in : {:.4f} s'.format(start_time-time.time()))
# Out:
# finished in : -5.8012 s

# %%
x= new_x 
x=np.delete(x, [0],axis=0)
y = np.arange(-32, 32)

print(x.shape)
# Out:
# (1000000, 2)

# %%
start_time = time.time()
Z = [ackley(np.array(x_i)) for x_i in x]
print('finished in : {:.4f} s' .format(start_time-time.time()))
# Out:
# finished in : -16.5737 s

# %%
X.shape
# Out:
# (1000, 1000)

# %%
new_z = np.array(Z)

# %%
new_z= new_z.reshape(1000,1000)

# %%
xlist = np.linspace(-32, 32, 1000)
ylist = np.linspace(-32, 32, 1000)

# start_time = time.time()
# Z = [ackley(np.array([x_i])) for x_i in x]
# print('finished in : {:.4f} s' .format(start_time-time.time()))

X, Y = np.meshgrid(xlist, ylist)

plt.figure(figsize=(9.6, 7.2), dpi=300)
cp = plt.contourf(X, Y, new_z)
plt.colorbar(cp)
plt.title('RMBO in 2D Ackley Function')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# Out:
# finished in : -23.5911 s

# %%
import matplotlib       

X, Y = np.meshgrid(xlist, ylist)

plt.figure(figsize=(9.6, 7.2), dpi=300)
# cp = plt.contourf(X, Y, new_z,cmap=cm.jet)
# cp = plt.contourf(X, Y, new_z,cmap=cm.RdYlGn)
# cp = plt.contourf(X, Y, new_z,cmap=cm.RdYlBu)
# cp = plt.contourf(X, Y, new_z,cmap=cm.jet_r)

# cp = plt.contourf(X, Y, new_z,cmap=cm.hsv_r)

# cp = plt.contourf(X, Y, new_z,cmap=cm.rainbow_r)


cp = plt.contourf(X, Y, new_z,cmap=cm.autumn)


plt.colorbar(cp)
plt.title('RMBO in 2D Ackley Function')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()
# plt.colorbar()
